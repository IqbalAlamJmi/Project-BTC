# %%
# importing all the necessary library used

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1,EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#labelling all the directory

labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
labels
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %%
#adding path, resizing and adding to list

X_train = []
y_train = []
image_size = 240
dir = '/content/drive/MyDrive/b'
for i in labels:
    folderPath = os.path.join(dir,'Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join(dir,'Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:10<00:00, 76.30it/s]
# 100%|██████████| 822/822 [00:12<00:00, 67.31it/s]
# 100%|██████████| 395/395 [00:03<00:00, 100.66it/s]
# 100%|██████████| 827/827 [00:15<00:00, 53.60it/s]
# 100%|██████████| 100/100 [00:01<00:00, 85.24it/s]
# 100%|██████████| 115/115 [00:01<00:00, 92.08it/s]
# 100%|██████████| 105/105 [00:01<00:00, 97.50it/s]
# 100%|██████████| 74/74 [00:21<00:00,  3.49it/s]

# %%
#displaying mri from each directory

k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Image Sample From Each Class',size=18,fontweight='bold',
             y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
#shuffling mri from each folder so that every time new set is generated

X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
#spliting data in train and test set

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
#one hot encoding 

y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
#checking number of images in each class in the training dataset

No_images_per_class = []
Class_name = []

for i in os.listdir('/content/drive/MyDrive/b/Training'):
  train_class = os.listdir(os.path.join('/content/drive/MyDrive/b/Training', i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in pituitary_tumor = 827
#
# Number of images in no_tumor = 395
#
# Number of images in meningioma_tumor = 822
#
# Number of images in glioma_tumor = 826

# %%
#visualizing class distribution in train set

plt.figure(figsize=(8, 8))
colors = sns.color_palette('pastel')
plt.pie(No_images_per_class, 
        labels = Class_name, 
        autopct = '%1.1f%%',
        colors=colors)
plt.show()

# %%
#visualizing class distribution in train set and test set

train_labels = []
test_labels = []

dir = '/content/drive/MyDrive/b'

img_size= 240

for i in os.listdir(dir+'/Training/'):
    for j in os.listdir(dir+"/Training/"+i):
       train_labels.append(i)
        
for i in os.listdir(dir+'/Testing/'):
    for j in os.listdir(dir+"/Testing/"+i):
        test_labels.append(i)

plt.figure(figsize = (17,8));
lis = ['Train', 'Test']
for i,j in enumerate([train_labels, test_labels]):
    plt.subplot(1,2, i+1);
    sns.countplot(x = j);
    plt.xlabel(lis[i])

# %%
#VGG16

from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPool2D, BatchNormalization
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.applications.vgg16 import VGG16

image_size = 240
vg = VGG16(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))

model = vg.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=vg.input, outputs = model)

model.summary()

model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("modeldatasetb.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)


history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,earlystop,reduce_lr])

#Visualize Training
def plot_graphs(history, string):
    sns.set_style("whitegrid")
    plt.plot(history.history[string])
    plt.plot(history.history["val_"+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.title("Brain Tumor Model-15 Epochs")
    plt.legend([string,"val_"+string])
    plt.show()
plot_graphs(history,'accuracy')
plot_graphs(history,'loss')


#classification report
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
print(classification_report(y_test_new,pred))





#confusin matrix
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True)
fig.text(s='Heatmap of the Confusion Matrix',size=12,y=0.92,x=0.28,alpha=0.8)

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 240, 240, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 240, 240, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 120, 120, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 120, 120, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 120, 120, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 60, 60, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 60, 60, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 60, 60, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 60, 60, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 30, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 30, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 14,716,740
# Trainable params: 14,716,740
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 3.8186 - accuracy: 0.3042
# Epoch 1: val_accuracy improved from -inf to 0.37755, saving model to modeldatasetb.h5
# 83/83 [==============================] - 59s 606ms/step - loss: 3.8186 - accuracy: 0.3042 - val_loss: 1.2971 - val_accuracy: 0.3776 - lr: 0.0010
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 1.2295 - accuracy: 0.3768
# Epoch 2: val_accuracy improved from 0.37755 to 0.46599, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 509ms/step - loss: 1.2295 - accuracy: 0.3768 - val_loss: 1.2063 - val_accuracy: 0.4660 - lr: 0.0010
# Epoch 3/50
# 83/83 [==============================] - ETA: 0s - loss: 1.1705 - accuracy: 0.4389
# Epoch 3: val_accuracy did not improve from 0.46599
# 83/83 [==============================] - 41s 493ms/step - loss: 1.1705 - accuracy: 0.4389 - val_loss: 1.1699 - val_accuracy: 0.4286 - lr: 0.0010
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 1.1429 - accuracy: 0.5013
# Epoch 4: val_accuracy improved from 0.46599 to 0.50340, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 511ms/step - loss: 1.1429 - accuracy: 0.5013 - val_loss: 1.1208 - val_accuracy: 0.5034 - lr: 0.0010
# Epoch 5/50
# 83/83 [==============================] - ETA: 0s - loss: 1.1112 - accuracy: 0.4858
# Epoch 5: val_accuracy improved from 0.50340 to 0.51701, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 512ms/step - loss: 1.1112 - accuracy: 0.4858 - val_loss: 1.0727 - val_accuracy: 0.5170 - lr: 0.0010
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.5664
# Epoch 6: val_accuracy did not improve from 0.51701
# 83/83 [==============================] - 41s 493ms/step - loss: 0.9975 - accuracy: 0.5664 - val_loss: 0.9824 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 0.8830 - accuracy: 0.6277
# Epoch 7: val_accuracy improved from 0.51701 to 0.64626, saving model to modeldatasetb.h5
# 83/83 [==============================] - 43s 513ms/step - loss: 0.8830 - accuracy: 0.6277 - val_loss: 0.8622 - val_accuracy: 0.6463 - lr: 0.0010
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.8145 - accuracy: 0.6795
# Epoch 8: val_accuracy did not improve from 0.64626
# 83/83 [==============================] - 42s 506ms/step - loss: 0.8145 - accuracy: 0.6795 - val_loss: 0.8748 - val_accuracy: 0.6190 - lr: 0.0010
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.7418 - accuracy: 0.6939
# Epoch 9: val_accuracy improved from 0.64626 to 0.67007, saving model to modeldatasetb.h5
# 83/83 [==============================] - 41s 500ms/step - loss: 0.7418 - accuracy: 0.6939 - val_loss: 0.7651 - val_accuracy: 0.6701 - lr: 0.0010
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6830 - accuracy: 0.7140
# Epoch 10: val_accuracy improved from 0.67007 to 0.71429, saving model to modeldatasetb.h5
# 83/83 [==============================] - 43s 513ms/step - loss: 0.6830 - accuracy: 0.7140 - val_loss: 0.6783 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.7330 - accuracy: 0.7109
# Epoch 11: val_accuracy did not improve from 0.71429
# 83/83 [==============================] - 41s 495ms/step - loss: 0.7330 - accuracy: 0.7109 - val_loss: 0.7723 - val_accuracy: 0.6837 - lr: 0.0010
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6513 - accuracy: 0.7246
# Epoch 12: val_accuracy did not improve from 0.71429
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 42s 508ms/step - loss: 0.6513 - accuracy: 0.7246 - val_loss: 0.6928 - val_accuracy: 0.7007 - lr: 0.0010
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5603 - accuracy: 0.7692
# Epoch 13: val_accuracy improved from 0.71429 to 0.75510, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 512ms/step - loss: 0.5603 - accuracy: 0.7692 - val_loss: 0.6055 - val_accuracy: 0.7551 - lr: 3.0000e-04
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.7760
# Epoch 14: val_accuracy did not improve from 0.75510
# 83/83 [==============================] - 41s 495ms/step - loss: 0.5265 - accuracy: 0.7760 - val_loss: 0.5759 - val_accuracy: 0.7551 - lr: 3.0000e-04
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5033 - accuracy: 0.7843
# Epoch 15: val_accuracy did not improve from 0.75510
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 [==============================] - 42s 508ms/step - loss: 0.5033 - accuracy: 0.7843 - val_loss: 0.5604 - val_accuracy: 0.7449 - lr: 3.0000e-04
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.8014
# Epoch 16: val_accuracy improved from 0.75510 to 0.76190, saving model to modeldatasetb.h5
# 83/83 [==============================] - 43s 513ms/step - loss: 0.4578 - accuracy: 0.8014 - val_loss: 0.5566 - val_accuracy: 0.7619 - lr: 9.0000e-05
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4407 - accuracy: 0.8093
# Epoch 17: val_accuracy improved from 0.76190 to 0.77551, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 512ms/step - loss: 0.4407 - accuracy: 0.8093 - val_loss: 0.5350 - val_accuracy: 0.7755 - lr: 9.0000e-05
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8127
# Epoch 18: val_accuracy did not improve from 0.77551
# 83/83 [==============================] - 41s 495ms/step - loss: 0.4356 - accuracy: 0.8127 - val_loss: 0.5258 - val_accuracy: 0.7721 - lr: 9.0000e-05
# Epoch 19/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4129 - accuracy: 0.8229
# Epoch 19: val_accuracy improved from 0.77551 to 0.79252, saving model to modeldatasetb.h5
# 83/83 [==============================] - 43s 514ms/step - loss: 0.4129 - accuracy: 0.8229 - val_loss: 0.5182 - val_accuracy: 0.7925 - lr: 9.0000e-05
# Epoch 20/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4099 - accuracy: 0.8229
# Epoch 20: val_accuracy did not improve from 0.79252
# 83/83 [==============================] - 41s 497ms/step - loss: 0.4099 - accuracy: 0.8229 - val_loss: 0.5102 - val_accuracy: 0.7891 - lr: 9.0000e-05
# Epoch 21/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8309
# Epoch 21: val_accuracy did not improve from 0.79252
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 [==============================] - 41s 498ms/step - loss: 0.3852 - accuracy: 0.8309 - val_loss: 0.5519 - val_accuracy: 0.7823 - lr: 9.0000e-05
# Epoch 22/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3723 - accuracy: 0.8445
# Epoch 22: val_accuracy did not improve from 0.79252
# 83/83 [==============================] - 42s 512ms/step - loss: 0.3723 - accuracy: 0.8445 - val_loss: 0.5373 - val_accuracy: 0.7925 - lr: 2.7000e-05
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3625 - accuracy: 0.8490
# Epoch 23: val_accuracy improved from 0.79252 to 0.79592, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 502ms/step - loss: 0.3625 - accuracy: 0.8490 - val_loss: 0.5342 - val_accuracy: 0.7959 - lr: 2.7000e-05
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.8562
# Epoch 24: val_accuracy did not improve from 0.79592
# 83/83 [==============================] - 42s 509ms/step - loss: 0.3521 - accuracy: 0.8562 - val_loss: 0.5388 - val_accuracy: 0.7925 - lr: 2.7000e-05
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3450 - accuracy: 0.8611
# Epoch 25: val_accuracy did not improve from 0.79592
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 [==============================] - 41s 497ms/step - loss: 0.3450 - accuracy: 0.8611 - val_loss: 0.5462 - val_accuracy: 0.7959 - lr: 2.7000e-05
# Epoch 26/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8577
# Epoch 26: val_accuracy improved from 0.79592 to 0.79932, saving model to modeldatasetb.h5
# 83/83 [==============================] - 42s 503ms/step - loss: 0.3464 - accuracy: 0.8577 - val_loss: 0.5364 - val_accuracy: 0.7993 - lr: 8.1000e-06
# Epoch 27/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3335 - accuracy: 0.8661
# Epoch 27: val_accuracy did not improve from 0.79932
# 83/83 [==============================] - 42s 509ms/step - loss: 0.3335 - accuracy: 0.8661 - val_loss: 0.5372 - val_accuracy: 0.7959 - lr: 8.1000e-06
# Epoch 28/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3409 - accuracy: 0.8668
# Epoch 28: val_accuracy did not improve from 0.79932
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 83/83 [==============================] - 41s 498ms/step - loss: 0.3409 - accuracy: 0.8668 - val_loss: 0.5388 - val_accuracy: 0.7993 - lr: 8.1000e-06
# Epoch 29/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3325 - accuracy: 0.8589
# Epoch 29: val_accuracy did not improve from 0.79932
# 83/83 [==============================] - 41s 498ms/step - loss: 0.3325 - accuracy: 0.8589 - val_loss: 0.5392 - val_accuracy: 0.7993 - lr: 2.4300e-06
# Epoch 30/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8657
# Epoch 30: val_accuracy did not improve from 0.79932
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 83/83 [==============================] - 42s 510ms/step - loss: 0.3380 - accuracy: 0.8657 - val_loss: 0.5386 - val_accuracy: 0.7993 - lr: 2.4300e-06
# Epoch 31/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.8611
# Epoch 31: val_accuracy did not improve from 0.79932
# 83/83 [==============================] - 42s 510ms/step - loss: 0.3337 - accuracy: 0.8611 - val_loss: 0.5385 - val_accuracy: 0.7993 - lr: 7.2900e-07
# Epoch 31: early stopping
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86        93
#            1       0.75      0.82      0.78        95
#            2       0.80      0.87      0.83        52
#            3       0.92      0.91      0.91        87
#
#     accuracy                           0.85       327
#    macro avg       0.85      0.85      0.85       327
# weighted avg       0.85      0.85      0.85       327

# %%
#VGG19

from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPool2D, BatchNormalization
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.applications.vgg19 import VGG19

image_size = 240
vg = VGG19(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))

model = vg.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=vg.input, outputs = model)

model.summary()

model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("modeldatasetb.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)


history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,earlystop,reduce_lr])

#Visualize Training
def plot_graphs(history, string):
    sns.set_style("whitegrid")
    plt.plot(history.history[string])
    plt.plot(history.history["val_"+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.title("Brain Tumor Model-15 Epochs")
    plt.legend([string,"val_"+string])
    plt.show()
plot_graphs(history,'accuracy')
plot_graphs(history,'loss')





#classification report
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
print(classification_report(y_test_new,pred))





#confusin matrix
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True)
fig.text(s='Heatmap of the Confusion Matrix',size=12,y=0.92,x=0.28,alpha=0.8)

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 240, 240, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 240, 240, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 240, 240, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 120, 120, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 120, 120, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 120, 120, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 60, 60, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 60, 60, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 60, 60, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 60, 60, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 60, 60, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 30, 30, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 30, 30, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 30, 30, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d_2   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 20,026,436
# Trainable params: 20,026,436
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 3.4634 - accuracy: 0.2766
# Epoch 1: val_accuracy improved from -inf to 0.28912, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 594ms/step - loss: 3.4634 - accuracy: 0.2766 - val_loss: 1.3350 - val_accuracy: 0.2891 - lr: 0.0010
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 1.3240 - accuracy: 0.3137
# Epoch 2: val_accuracy improved from 0.28912 to 0.40816, saving model to modeldatasetb.h5
# 83/83 [==============================] - 48s 581ms/step - loss: 1.3240 - accuracy: 0.3137 - val_loss: 1.3494 - val_accuracy: 0.4082 - lr: 0.0010
# Epoch 3/50
# 83/83 [==============================] - ETA: 0s - loss: 1.2632 - accuracy: 0.3871
# Epoch 3: val_accuracy did not improve from 0.40816
# 83/83 [==============================] - 48s 576ms/step - loss: 1.2632 - accuracy: 0.3871 - val_loss: 1.2840 - val_accuracy: 0.3980 - lr: 0.0010
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 1.2346 - accuracy: 0.4253
# Epoch 4: val_accuracy improved from 0.40816 to 0.44218, saving model to modeldatasetb.h5
# 83/83 [==============================] - 49s 596ms/step - loss: 1.2346 - accuracy: 0.4253 - val_loss: 1.1526 - val_accuracy: 0.4422 - lr: 0.0010
# Epoch 5/50
# 83/83 [==============================] - ETA: 0s - loss: 1.2153 - accuracy: 0.4404
# Epoch 5: val_accuracy improved from 0.44218 to 0.46259, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 599ms/step - loss: 1.2153 - accuracy: 0.4404 - val_loss: 1.1477 - val_accuracy: 0.4626 - lr: 0.0010
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 1.1266 - accuracy: 0.4911
# Epoch 6: val_accuracy improved from 0.46259 to 0.52041, saving model to modeldatasetb.h5
# 83/83 [==============================] - 49s 591ms/step - loss: 1.1266 - accuracy: 0.4911 - val_loss: 1.0257 - val_accuracy: 0.5204 - lr: 0.0010
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 1.0987 - accuracy: 0.5070
# Epoch 7: val_accuracy did not improve from 0.52041
# 83/83 [==============================] - 48s 583ms/step - loss: 1.0987 - accuracy: 0.5070 - val_loss: 1.1167 - val_accuracy: 0.4762 - lr: 0.0010
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.9972 - accuracy: 0.5649
# Epoch 8: val_accuracy did not improve from 0.52041
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 48s 585ms/step - loss: 0.9972 - accuracy: 0.5649 - val_loss: 1.0791 - val_accuracy: 0.4694 - lr: 0.0010
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.9019 - accuracy: 0.6163
# Epoch 9: val_accuracy improved from 0.52041 to 0.58503, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 601ms/step - loss: 0.9019 - accuracy: 0.6163 - val_loss: 0.8850 - val_accuracy: 0.5850 - lr: 3.0000e-04
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.8112 - accuracy: 0.6602
# Epoch 10: val_accuracy improved from 0.58503 to 0.61224, saving model to modeldatasetb.h5
# 83/83 [==============================] - 49s 596ms/step - loss: 0.8112 - accuracy: 0.6602 - val_loss: 0.8905 - val_accuracy: 0.6122 - lr: 3.0000e-04
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.7694 - accuracy: 0.6856
# Epoch 11: val_accuracy improved from 0.61224 to 0.65646, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 602ms/step - loss: 0.7694 - accuracy: 0.6856 - val_loss: 0.7942 - val_accuracy: 0.6565 - lr: 3.0000e-04
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.7279 - accuracy: 0.7037
# Epoch 12: val_accuracy improved from 0.65646 to 0.68707, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 602ms/step - loss: 0.7279 - accuracy: 0.7037 - val_loss: 0.7804 - val_accuracy: 0.6871 - lr: 3.0000e-04
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.7176 - accuracy: 0.7098
# Epoch 13: val_accuracy improved from 0.68707 to 0.70408, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 602ms/step - loss: 0.7176 - accuracy: 0.7098 - val_loss: 0.7240 - val_accuracy: 0.7041 - lr: 3.0000e-04
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6591 - accuracy: 0.7351
# Epoch 14: val_accuracy improved from 0.70408 to 0.72109, saving model to modeldatasetb.h5
# 83/83 [==============================] - 49s 594ms/step - loss: 0.6591 - accuracy: 0.7351 - val_loss: 0.6836 - val_accuracy: 0.7211 - lr: 3.0000e-04
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6204 - accuracy: 0.7526
# Epoch 15: val_accuracy did not improve from 0.72109
# 83/83 [==============================] - 49s 585ms/step - loss: 0.6204 - accuracy: 0.7526 - val_loss: 0.8251 - val_accuracy: 0.6769 - lr: 3.0000e-04
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6040 - accuracy: 0.7586
# Epoch 16: val_accuracy improved from 0.72109 to 0.74490, saving model to modeldatasetb.h5
# 83/83 [==============================] - 50s 603ms/step - loss: 0.6040 - accuracy: 0.7586 - val_loss: 0.6577 - val_accuracy: 0.7449 - lr: 3.0000e-04
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5774 - accuracy: 0.7764
# Epoch 17: val_accuracy did not improve from 0.74490
# 83/83 [==============================] - 49s 592ms/step - loss: 0.5774 - accuracy: 0.7764 - val_loss: 0.6801 - val_accuracy: 0.7177 - lr: 3.0000e-04
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5553 - accuracy: 0.7764
# Epoch 18: val_accuracy did not improve from 0.74490
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 [==============================] - 48s 584ms/step - loss: 0.5553 - accuracy: 0.7764 - val_loss: 0.6661 - val_accuracy: 0.7177 - lr: 3.0000e-04
# Epoch 19/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.8048
# Epoch 19: val_accuracy improved from 0.74490 to 0.76531, saving model to modeldatasetb.h5
# 83/83 [==============================] - 49s 596ms/step - loss: 0.5038 - accuracy: 0.8048 - val_loss: 0.5892 - val_accuracy: 0.7653 - lr: 9.0000e-05
# Epoch 20/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4848 - accuracy: 0.8089
# Epoch 20: val_accuracy did not improve from 0.76531
# 83/83 [==============================] - 49s 595ms/step - loss: 0.4848 - accuracy: 0.8089 - val_loss: 0.5713 - val_accuracy: 0.7517 - lr: 9.0000e-05
# Epoch 21/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4608 - accuracy: 0.8199
# Epoch 21: val_accuracy improved from 0.76531 to 0.77551, saving model to modeldatasetb.h5
# 83/83 [==============================] - 49s 593ms/step - loss: 0.4608 - accuracy: 0.8199 - val_loss: 0.5941 - val_accuracy: 0.7755 - lr: 9.0000e-05
# Epoch 22/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.8157
# Epoch 22: val_accuracy did not improve from 0.77551
# 83/83 [==============================] - 49s 594ms/step - loss: 0.4657 - accuracy: 0.8157 - val_loss: 0.5761 - val_accuracy: 0.7619 - lr: 9.0000e-05
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4593 - accuracy: 0.8150
# Epoch 23: val_accuracy did not improve from 0.77551
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 [==============================] - 49s 594ms/step - loss: 0.4593 - accuracy: 0.8150 - val_loss: 0.5740 - val_accuracy: 0.7687 - lr: 9.0000e-05
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8286
# Epoch 24: val_accuracy did not improve from 0.77551
# 83/83 [==============================] - 49s 586ms/step - loss: 0.4212 - accuracy: 0.8286 - val_loss: 0.5624 - val_accuracy: 0.7653 - lr: 2.7000e-05
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4133 - accuracy: 0.8328
# Epoch 25: val_accuracy did not improve from 0.77551
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 [==============================] - 49s 596ms/step - loss: 0.4133 - accuracy: 0.8328 - val_loss: 0.5515 - val_accuracy: 0.7755 - lr: 2.7000e-05
# Epoch 26/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8426
# Epoch 26: val_accuracy did not improve from 0.77551
# 83/83 [==============================] - 49s 587ms/step - loss: 0.4105 - accuracy: 0.8426 - val_loss: 0.5534 - val_accuracy: 0.7721 - lr: 8.1000e-06
# Epoch 26: early stopping
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85        93
#            1       0.75      0.79      0.77        95
#            2       0.74      0.83      0.78        52
#            3       0.88      0.92      0.90        87
#
#     accuracy                           0.83       327
#    macro avg       0.83      0.83      0.83       327
# weighted avg       0.84      0.83      0.83       327
