# %%
# importing all the necessary library used

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB1,EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output

# %%
#labelling all the directory

labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
labels
# Out:
# ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#adding path, resizing and adding to list

X_train = []
y_train = []
image_size = 240
dir = '/content/drive/MyDrive/b'
for i in labels:
    folderPath = os.path.join(dir,'Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join(dir,'Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:14<00:00, 56.99it/s]
# 100%|██████████| 822/822 [00:14<00:00, 57.61it/s]
# 100%|██████████| 395/395 [00:06<00:00, 62.45it/s]
# 100%|██████████| 827/827 [00:13<00:00, 59.59it/s]
# 100%|██████████| 100/100 [00:02<00:00, 39.18it/s]
# 100%|██████████| 115/115 [00:02<00:00, 46.26it/s]
# 100%|██████████| 105/105 [00:03<00:00, 32.03it/s]
# 100%|██████████| 74/74 [00:48<00:00,  1.53it/s]

# %%
#displaying mri from each directory

k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Image Sample From Each Class',size=18,fontweight='bold',
             y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
#shuffling mri from each folder so that every time new set is generated

X_train, y_train = shuffle(X_train,y_train, random_state=101)

# %%
#spliting data in train and test set

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
#one hot encoding 

y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
#checking number of images in each class in the training dataset

No_images_per_class = []
Class_name = []

for i in os.listdir('/content/drive/MyDrive/b/Training'):
  train_class = os.listdir(os.path.join('/content/drive/MyDrive/b/Training', i))
  No_images_per_class.append(len(train_class))
  Class_name.append(i)
  print('Number of images in {} = {} \n'.format(i, len(train_class)))
# Out:
# Number of images in pituitary_tumor = 827
#
# Number of images in no_tumor = 395
#
# Number of images in glioma_tumor = 826
#
# Number of images in meningioma_tumor = 822

# %%
#visualizing class distribution in train set

plt.figure(figsize=(8, 8))
colors = sns.color_palette('pastel')
plt.pie(No_images_per_class, 
        labels = Class_name, 
        autopct = '%1.1f%%',
        colors=colors)
plt.show()

# %%
#visualizing class distribution in train set and test set

train_labels = []
test_labels = []

dir = '/content/drive/MyDrive/b'

img_size= 240

for i in os.listdir(dir+'/Training/'):
    for j in os.listdir(dir+"/Training/"+i):
       train_labels.append(i)
        
for i in os.listdir(dir+'/Testing/'):
    for j in os.listdir(dir+"/Testing/"+i):
        test_labels.append(i)

plt.figure(figsize = (17,8));
lis = ['Train', 'Test']
for i,j in enumerate([train_labels, test_labels]):
    plt.subplot(1,2, i+1);
    sns.countplot(x = j);
    plt.xlabel(lis[i])

# %%
#Xception

from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D


from tensorflow.keras.applications import Xception
image_size = 240
m = Xception(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))

model = m.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=m.input, outputs = model)

model.summary()

model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("modelxception.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)


history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,earlystop,reduce_lr])
#Visualize Training
def plot_graphs(history, string):
    sns.set_style("whitegrid")
    plt.plot(history.history[string])
    plt.plot(history.history["val_"+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.title("Brain Tumor Model-15 Epochs")
    plt.legend([string,"val_"+string])
    plt.show()
plot_graphs(history,'accuracy')
plot_graphs(history,'loss')

#classification report
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
print(classification_report(y_test_new,pred))

#confusin matrix
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True)
fig.text(s='Heatmap of the Confusion Matrix',size=12,y=0.92,x=0.28,alpha=0.8)

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 2s 0us/step
# 83697664/83683744 [==============================] - 2s 0us/step
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 240, 240, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 119, 119, 32  864         ['input_8[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 119, 119, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 119, 119, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 117, 117, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 117, 117, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 117, 117, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 117, 117, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 117, 117, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 117, 117, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None,
- val_accuracy: 0.7143 - lr: 0.0010
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9818
# Epoch 7: val_accuracy improved from 0.78231 to 0.94558, saving model to modelxception.h5
# 83/83 [==============================] - 60s 728ms/step - loss: 0.0612 - accuracy: 0.9818 - val_loss: 0.1870 - val_accuracy: 0.9456 - lr: 0.0010
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9939
# Epoch 8: val_accuracy did not improve from 0.94558
# 83/83 [==============================] - 60s 718ms/step - loss: 0.0250 - accuracy: 0.9939 - val_loss: 0.5179 - val_accuracy: 0.8503 - lr: 0.0010
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9667
# Epoch 9: val_accuracy did not improve from 0.94558
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 58s 702ms/step - loss: 0.0994 - accuracy: 0.9667 - val_loss: 0.5216 - val_accuracy: 0.8197 - lr: 0.0010
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9924
# Epoch 10: val_accuracy improved from 0.94558 to 0.95578, saving model to modelxception.h5
# 83/83 [==============================] - 60s 729ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.1169 - val_accuracy: 0.9558 - lr: 3.0000e-04
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9970
# Epoch 11: val_accuracy improved from 0.95578 to 0.96939, saving model to modelxception.h5
# 83/83 [==============================] - 60s 717ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.0918 - val_accuracy: 0.9694 - lr: 3.0000e-04
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9996
# Epoch 12: val_accuracy improved from 0.96939 to 0.97619, saving model to modelxception.h5
# 83/83 [==============================] - 60s 729ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.0813 - val_accuracy: 0.9762 - lr: 3.0000e-04
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 13: val_accuracy improved from 0.97619 to 0.97959, saving model to modelxception.h5
# 83/83 [==============================] - 59s 715ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0819 - val_accuracy: 0.9796 - lr: 3.0000e-04
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9996
# Epoch 14: val_accuracy improved from 0.97959 to 0.98299, saving model to modelxception.h5
# 83/83 [==============================] - 61s 731ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0750 - val_accuracy: 0.9830 - lr: 3.0000e-04
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9996
# Epoch 15: val_accuracy did not improve from 0.98299
# 83/83 [==============================] - 60s 717ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0734 - val_accuracy: 0.9796 - lr: 3.0000e-04
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 0.98299
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 [==============================] - 59s 716ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9796 - lr: 3.0000e-04
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 6.7148e-04 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 0.98299
# 83/83 [==============================] - 61s 731ms/step - loss: 6.7148e-04 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9762 - lr: 9.0000e-05
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 18: val_accuracy did not improve from 0.98299
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 [==============================] - 58s 704ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0786 - val_accuracy: 0.9762 - lr: 9.0000e-05
# Epoch 19/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.98299
# 83/83 [==============================] - 60s 718ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9762 - lr: 2.7000e-05
# Epoch 19: early stopping
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        93
#            1       0.96      0.95      0.95        95
#            2       0.98      1.00      0.99        52
#            3       0.98      1.00      0.99        87
#
#     accuracy                           0.97       327
#    macro avg       0.97      0.98      0.97       327
# weighted avg       0.97      0.97      0.97       327

# %%
#DenseNet

from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D

from tensorflow.keras.applications import DenseNet121
image_size = 240
m = DenseNet121(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))

model = m.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=m.input, outputs = model)

model.summary()

model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("modeldensenet.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)


history = model.fit(X_train,y_train,validation_split=0.1, epochs =50, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,earlystop,reduce_lr])
#Visualize Training
def plot_graphs(history, string):
    sns.set_style("whitegrid")
    plt.plot(history.history[string])
    plt.plot(history.history["val_"+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.title("Brain Tumor Model-15 Epochs")
    plt.legend([string,"val_"+string])
    plt.show()
plot_graphs(history,'accuracy')
plot_graphs(history,'loss')

#classification report
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
print(classification_report(y_test_new,pred))

#confusin matrix
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True)
fig.text(s='Heatmap of the Confusion Matrix',size=12,y=0.92,x=0.28,alpha=0.8)

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 240, 240, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 246, 246, 3)  0          ['input_9[0][0]']
#
#  conv1/conv (Conv2D)            (None, 120, 120, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 120, 120, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 120, 120, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 122, 122, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 60, 60, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 60, 60, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 60, 60, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 60, 60, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 60, 60, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 60, 60, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 60, 60, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 60, 60, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 60, 60, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 60, 60, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 60, 60, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 60, 60, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 60, 60, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 60, 60, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 60, 60, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 60, 60, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 60, 60, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 60, 60, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 60, 60, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 60, 60, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 60, 60, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 60, 60, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 60, 60, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 60, 60, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 60, 60, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 60, 60, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 60, 60, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 60, 60, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 60, 60, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 60, 60, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 60, 60, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 60, 60, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 60, 60, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 60, 60, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 30, 30, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 30, 30, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 30, 30, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 30, 30, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 30, 30, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 30, 30, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 30, 30, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 30, 30, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 30, 30, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 30, 30, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 30, 30, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 30, 30, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 30, 30, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 30, 30, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 30, 30, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 30, 30, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 30, 30, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 30, 30, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 30, 30, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 30, 30, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 30, 30, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 30, 30, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 30, 30, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 30, 30, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 30, 30, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 30, 30, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 30, 30, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 30, 30, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 30, 30, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 30, 30, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 30, 30, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 30, 30, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 30, 30, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 30, 30, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 30, 30, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 30, 30, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 30, 30, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 30, 30, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 30, 30, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 30, 30, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 30, 30, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 30, 30, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 30, 30, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 30, 30, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 30, 30, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 30, 30, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 30, 30, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 30, 30, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 30, 30, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 30, 30, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 30, 30, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 30, 30, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 30, 30, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 30, 30, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 30, 30, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 30, 30, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 30, 30, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 30, 30, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 30, 30, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 30, 30, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 30, 30, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 30, 30, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 30, 30, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 15, 15, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 15, 15, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 15, 15, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 15, 15, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 15, 15, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 15, 15, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 15, 15, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 15, 15, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 15, 15, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 15, 15, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 15, 15, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 15, 15, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 15, 15, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 15, 15, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 15, 15, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 15, 15, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 15, 15, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 15, 15, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 15, 15, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 15, 15, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 15, 15, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 15, 15, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 15, 15, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 15, 15, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 15, 15, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
# ...
#
#  conv5_block12_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 7, 7, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 7, 7, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 7, 7, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 7, 7, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 7, 7, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 7, 7, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 7, 7, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 7, 7, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 7, 7, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 7, 7, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 7, 7, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 7, 7, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 7, 7, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 7, 7, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 7, 7, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 7, 7, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 7, 7, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 1024)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  dropout_10 (Dropout)           (None, 1024)         0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 4)            4100        ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 7,041,604
# Trainable params: 6,957,956
# Non-trainable params: 83,648
# __________________________________________________________________________________________________
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6761 - accuracy: 0.7601
# Epoch 1: val_accuracy improved from -inf to 0.45238, saving model to modeldensenet.h5
# 83/83 [==============================] - 57s 507ms/step - loss: 0.6761 - accuracy: 0.7601 - val_loss: 3.0943 - val_accuracy: 0.4524 - lr: 0.0010
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8823
# Epoch 2: val_accuracy improved from 0.45238 to 0.74490, saving model to modeldensenet.h5
# 83/83 [==============================] - 36s 429ms/step - loss: 0.3575 - accuracy: 0.8823 - val_loss: 4.0096 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 3/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.9224
# Epoch 3: val_accuracy did not improve from 0.74490
# 83/83 [==============================] - 35s 420ms/step - loss: 0.2423 - accuracy: 0.9224 - val_loss: 4.8742 - val_accuracy: 0.2279 - lr: 0.0010
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1969 - accuracy: 0.9402
# Epoch 4: val_accuracy improved from 0.74490 to 0.91156, saving model to modeldensenet.h5
# 83/83 [==============================] - 36s 431ms/step - loss: 0.1969 - accuracy: 0.9402 - val_loss: 0.3013 - val_accuracy: 0.9116 - lr: 0.0010
# Epoch 5/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9432
# Epoch 5: val_accuracy did not improve from 0.91156
# 83/83 [==============================] - 34s 415ms/step - loss: 0.1485 - accuracy: 0.9432 - val_loss: 1.7072 - val_accuracy: 0.7041 - lr: 0.0010
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9618
# Epoch 6: val_accuracy did not improve from 0.91156
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 35s 416ms/step - loss: 0.1102 - accuracy: 0.9618 - val_loss: 2.1371 - val_accuracy: 0.4456 - lr: 0.0010
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9781
# Epoch 7: val_accuracy improved from 0.91156 to 0.93878, saving model to modeldensenet.h5
# 83/83 [==============================] - 36s 435ms/step - loss: 0.0818 - accuracy: 0.9781 - val_loss: 0.2084 - val_accuracy: 0.9388 - lr: 3.0000e-04
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9932
# Epoch 8: val_accuracy did not improve from 0.93878
# 83/83 [==============================] - 35s 417ms/step - loss: 0.0251 - accuracy: 0.9932 - val_loss: 0.1949 - val_accuracy: 0.9354 - lr: 3.0000e-04
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9955
# Epoch 9: val_accuracy improved from 0.93878 to 0.94558, saving model to modeldensenet.h5
# 83/83 [==============================] - 36s 436ms/step - loss: 0.0165 - accuracy: 0.9955 - val_loss: 0.1511 - val_accuracy: 0.9456 - lr: 3.0000e-04
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9985
# Epoch 10: val_accuracy improved from 0.94558 to 0.96939, saving model to modeldensenet.h5
# 83/83 [==============================] - 36s 433ms/step - loss: 0.0094 - accuracy: 0.9985 - val_loss: 0.1352 - val_accuracy: 0.9694 - lr: 3.0000e-04
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9977
# Epoch 11: val_accuracy did not improve from 0.96939
# 83/83 [==============================] - 35s 420ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.2532 - val_accuracy: 0.9286 - lr: 3.0000e-04
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9977
# Epoch 12: val_accuracy did not improve from 0.96939
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 83/83 [==============================] - 35s 420ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.1392 - val_accuracy: 0.9660 - lr: 3.0000e-04
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9989
# Epoch 13: val_accuracy improved from 0.96939 to 0.97279, saving model to modeldensenet.h5
# 83/83 [==============================] - 36s 435ms/step - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.1226 - val_accuracy: 0.9728 - lr: 9.0000e-05
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9996
# Epoch 14: val_accuracy did not improve from 0.97279
# 83/83 [==============================] - 35s 416ms/step - loss: 0.0045 - accuracy: 0.9996 - val_loss: 0.1285 - val_accuracy: 0.9694 - lr: 9.0000e-05
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9985
# Epoch 15: val_accuracy did not improve from 0.97279
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 83/83 [==============================] - 35s 417ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.1333 - val_accuracy: 0.9660 - lr: 9.0000e-05
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9996
# Epoch 16: val_accuracy did not improve from 0.97279
# 83/83 [==============================] - 35s 420ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 0.1247 - val_accuracy: 0.9694 - lr: 2.7000e-05
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9996
# Epoch 17: val_accuracy did not improve from 0.97279
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 83/83 [==============================] - 35s 416ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.1235 - val_accuracy: 0.9694 - lr: 2.7000e-05
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 18: val_accuracy did not improve from 0.97279
# 83/83 [==============================] - 35s 419ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9694 - lr: 8.1000e-06
# Epoch 18: early stopping
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        93
#            1       0.94      0.96      0.95        95
#            2       0.96      0.94      0.95        52
#            3       0.98      1.00      0.99        87
#
#     accuracy                           0.97       327
#    macro avg       0.97      0.96      0.97       327
# weighted avg       0.97      0.97      0.97       327
